# %%
print("Olá, seja bem vindo ao nosso suporte acadêmico. Para saber informações acerca das suas notas preciso que me indique alguns dados")

nome = input("Digite seu nome:")
idade = int(input("Digite a sua idade: "))
print("Utilize apenas números e pontos")
nota1 = float(input("Digite a sua primeira nota em Python: "))
nota2 = float(input("Digite a sua segunda nota em Python:"))

soma = nota1 + nota2
print("A soma das suas notas é de: ", soma)

media = soma / 2
print("A média das suas notas é de: ", media)

diferença = nota1 - nota2
print("A diferença entre as suas notas é de: ", diferença)

aluno_reprovado = []
aluno_aprovado = []

if media > 85:
  print("Parabéns! Você concluiu o curso")
else:
  print("Aluno reprovado!")
  print("Para conseguir ser aprovado deverá realizar a prova novamente!")
# Out:
# Olá, seja bem vindo ao nosso suporte acadêmico. Para saber informações acerca das suas notas preciso que me indique alguns dados
# Digite seu nome:Giulia
# Digite a sua idade: 21
# Utilize apenas números e pontos
# Digite a sua primeira nota em Python: 56.9
# Digite a sua segunda nota em Python:97.5
# A soma das suas notas é de:  154.4
# A média das suas notas é de:  77.2
# A diferença entre as suas notas é de:  -40.6
# Aluno reprovado!
# Para conseguir ser aprovado deverá realizar a prova novamente!
